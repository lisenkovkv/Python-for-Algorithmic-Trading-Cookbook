# %% [markdown]
# ## Examining and selecting data from DataFrames

# %%
import pandas as pd
from IPython.display import display
from openbb import obb

# %%
obb.user.preferences.output_type = "dataframe"

# %% [markdown]
# Fetches historical price data for the equity "AAPL" starting from 2021-01-01 using the "yfinance" provider and stores it in 'df'

# %%
df = obb.equity.price.historical("AAPL", start_date="2021-01-01", provider="yfinance")

# %%
display()

# %% [markdown]
# Displays the first 5 rows of 'df'

# %%
ddf = df.head(5)

# %%
display()

# %% [markdown]
# Displays the last 5 rows of 'df'

# %%
ddf = df.tail(5)

# %%
display()

# %% [markdown]
# Displays the values of 'df'

# %%
display(df.values)
# Out:
# array([[1.33520004e+02, 1.33610001e+02, 1.26760002e+02, 1.29410004e+02,
#         1.43301900e+08, 0.00000000e+00],
#        [1.28889999e+02, 1.31740005e+02, 1.28429993e+02, 1.31009995e+02,
#         9.76649000e+07, 0.00000000e+00],
#        [1.27720001e+02, 1.31050003e+02, 1.26379997e+02, 1.26599998e+02,
#         1.55088000e+08, 0.00000000e+00],
#        ...,
#        [2.34119995e+02, 2.39860001e+02, 2.34009995e+02, 2.39360001e+02,
#         4.54861000e+07, 0.00000000e+00],
#        [2.38669998e+02, 2.40789993e+02, 2.37210007e+02, 2.37589996e+02,
#         5.56583000e+07, 0.00000000e+00],
#        [2.47190002e+02, 2.47190002e+02, 2.33440002e+02, 2.36000000e+02,
#         1.00959800e+08, 0.00000000e+00]], shape=(1025, 6))

# %% [markdown]
# Displays the statistical summary of 'df'

# %%
ddf = df.describe()

# %%
display()

# %% [markdown]
# Transposes 'df' and displays it

# %%
ddf = df.T

# %%
display()

# %% [markdown]
# Displays the column names of 'df'

# %%
display(df.columns)
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'dividend'], dtype='object')

# %% [markdown]
# Updates the column names of 'df'

# %%
df.columns = [
    "open",
    "high",
    "low",
    "close",
    "volume",
    "dividends",
    "splits",
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.columns = [
#       2     "open",
#       3     "high",
#       4     "low",
#       5     "close",
#       6     "volume",
#       7     "dividends",
#       8     "splits",
#       9 ]
#
# File ~/Documents/Python-for-Algorithmic-Trading-Cookbook/algo/lib/python3.10/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/Documents/Python-for-Algorithmic-Trading-Cookbook/algo/lib/python3.10/site-packages/pandas/core/generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File ~/Documents/Python-for-Algorithmic-Trading-Cookbook/algo/lib/python3.10/site-packages/pandas/core/internals/managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~/Documents/Python-for-Algorithmic-Trading-Cookbook/algo/lib/python3.10/site-packages/pandas/core/internals/base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 7 elements

# %%
display(df)
# Out:
#                   open        high         low       close     volume  \
# date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  143301900
# 2021-01-05  128.889999  131.740005  128.429993  131.009995   97664900
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  155088000
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# ...                ...         ...         ...         ...        ...
# 2025-01-27  224.020004  232.149994  223.979996  229.860001   94863400
# 2025-01-28  230.850006  240.190002  230.809998  238.259995   75707600
# 2025-01-29  234.119995  239.860001  234.009995  239.360001   45486100
# 2025-01-30  238.669998  240.789993  237.210007  237.589996   55658300
# 2025-01-31  247.190002  247.190002  233.440002  236.000000  100959800
#
#             dividend
# date
# 2021-01-04       0.0
# 2021-01-05       0.0
# 2021-01-06       0.0
# 2021-01-07       0.0
# 2021-01-08       0.0
# ...              ...
# 2025-01-27       0.0
# 2025-01-28       0.0
# 2025-01-29       0.0
# 2025-01-30       0.0
# 2025-01-31       0.0
#
# [1025 rows x 6 columns]

# %% [markdown]
# Accesses the 'close' column using two different methods

# %%
df["close"]
df.close
# Out:
# date
# 2021-01-04    129.410004
# 2021-01-05    131.009995
# 2021-01-06    126.599998
# 2021-01-07    130.919998
# 2021-01-08    132.050003
#                  ...
# 2025-01-27    229.860001
# 2025-01-28    238.259995
# 2025-01-29    239.360001
# 2025-01-30    237.589996
# 2025-01-31    236.000000
# Name: close, Length: 1025, dtype: float64

# %% [markdown]
# Slices the first three rows of 'df'

# %%
df[0:3]
# Out:
#                   open        high         low       close     volume  \
# date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  143301900
# 2021-01-05  128.889999  131.740005  128.429993  131.009995   97664900
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  155088000
#
#             dividend
# date
# 2021-01-04       0.0
# 2021-01-05       0.0
# 2021-01-06       0.0

# %% [markdown]
# Slices 'df' by date range (inclusive of the last value) after converting the index to datetime

# %%
df.index = pd.to_datetime(df.index)
df["2021-01-02":"2021-01-11"]
# Out:
#                   open        high         low       close     volume  \
# date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  143301900
# 2021-01-05  128.889999  131.740005  128.429993  131.009995   97664900
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  155088000
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  105158200
# 2021-01-11  129.190002  130.169998  128.500000  128.979996  100384500
#
#             dividend
# date
# 2021-01-04       0.0
# 2021-01-05       0.0
# 2021-01-06       0.0
# 2021-01-07       0.0
# 2021-01-08       0.0
# 2021-01-11       0.0

# %% [markdown]
# Displays the index (dates) of 'df'

# %%
dates = df.index

# %%
display()

# %% [markdown]
# Accesses the first date in the index

# %%
dates[0]
# Out:
# Timestamp('2021-01-04 00:00:00')

# %% [markdown]
# Accesses the row corresponding to the first date in the index

# %%
df.loc[df.index[0]]
# Out:
# open        1.335200e+02
# high        1.336100e+02
# low         1.267600e+02
# close       1.294100e+02
# volume      1.433019e+08
# dividend    0.000000e+00
# Name: 2021-01-04 00:00:00, dtype: float64

# %% [markdown]
# Accesses the 'close' value for the first date in the index

# %%
df.loc[df.index[0], "close"]
# Out:
# np.float64(129.41000366210938)

# %% [markdown]
# Accesses the 'open' and 'close' values for the first date in the index

# %%
df.loc[df.index[0], ["open", "close"]]
# Out:
# open     133.520004
# close    129.410004
# Name: 2021-01-04 00:00:00, dtype: float64

# %% [markdown]
# Slices the first six rows and selects the 'open' and 'close' columns

# %%
df.loc[df.index[0:6], ["open", "close"]]
# Out:
#                   open       close
# date
# 2021-01-04  133.520004  129.410004
# 2021-01-05  128.889999  131.009995
# 2021-01-06  127.720001  126.599998
# 2021-01-07  128.360001  130.919998
# 2021-01-08  132.429993  132.050003
# 2021-01-11  129.190002  128.979996

# %% [markdown]
# Slices 'df' by date range and selects the 'open' and 'close' columns

# %%
df.loc["2021-01-02":"2021-01-11", ["open", "close"]]
# Out:
#                   open       close
# date
# 2021-01-04  133.520004  129.410004
# 2021-01-05  128.889999  131.009995
# 2021-01-06  127.720001  126.599998
# 2021-01-07  128.360001  130.919998
# 2021-01-08  132.429993  132.050003
# 2021-01-11  129.190002  128.979996

# %% [markdown]
# Accesses the fourth row of 'df' using integer location

# %%
df.iloc[3]
# Out:
# open        1.283600e+02
# high        1.316300e+02
# low         1.278600e+02
# close       1.309200e+02
# volume      1.095782e+08
# dividend    0.000000e+00
# Name: 2021-01-07 00:00:00, dtype: float64

# %% [markdown]
# Slices the third and fourth rows and the first two columns using integer location

# %%
df.iloc[3:5, 0:2]
# Out:
#                   open        high
# date
# 2021-01-07  128.360001  131.630005
# 2021-01-08  132.429993  132.630005

# %% [markdown]
# Selects specific rows and columns by integer position

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                   open         low
# date
# 2021-01-05  128.889999  128.429993
# 2021-01-06  127.720001  126.379997
# 2021-01-08  132.429993  130.229996

# %% [markdown]
# Slices rows explicitly using integer location

# %%
df.iloc[1:3, :]
# Out:
#                   open        high         low       close     volume  \
# date
# 2021-01-05  128.889999  131.740005  128.429993  131.009995   97664900
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  155088000
#
#             dividend
# date
# 2021-01-05       0.0
# 2021-01-06       0.0

# %% [markdown]
# Slices columns explicitly using integer location

# %%
df.iloc[:, 1:3]
# Out:
#                   high         low
# date
# 2021-01-04  133.610001  126.760002
# 2021-01-05  131.740005  128.429993
# 2021-01-06  131.050003  126.379997
# 2021-01-07  131.630005  127.860001
# 2021-01-08  132.630005  130.229996
# ...                ...         ...
# 2025-01-27  232.149994  223.979996
# 2025-01-28  240.190002  230.809998
# 2025-01-29  239.860001  234.009995
# 2025-01-30  240.789993  237.210007
# 2025-01-31  247.190002  233.440002
#
# [1025 rows x 2 columns]

# %% [markdown]
# Accesses a specific value using integer location

# %%
df.iloc[1, 1]
# Out:
# np.float64(131.74000549316406)

# %% [markdown]
# Accesses a specific value using fast access method

# %%
df.iat[1, 1]
# Out:
# np.float64(131.74000549316406)

# %% [markdown]
# Uses boolean indexing to select data where 'close' is greater than the mean 'close' value

# %%
df.close > df.close.mean()
# Out:
# date
# 2021-01-04    False
# 2021-01-05    False
# 2021-01-06    False
# 2021-01-07    False
# 2021-01-08    False
#               ...
# 2025-01-27     True
# 2025-01-28     True
# 2025-01-29     True
# 2025-01-30     True
# 2025-01-31     True
# Name: close, Length: 1025, dtype: bool

# %%
df[df.close > df.close.mean()]
# Out:
#                   open        high         low       close     volume  \
# date
# 2021-12-07  169.080002  171.580002  168.339996  171.179993  120405400
# 2021-12-08  172.130005  175.960007  170.699997  175.080002  116998900
# 2021-12-09  174.910004  176.750000  173.919998  174.559998  108923700
# 2021-12-10  175.210007  179.630005  174.690002  179.449997  115402700
# 2021-12-13  181.119995  182.130005  175.529999  175.740005  153237000
# ...                ...         ...         ...         ...        ...
# 2025-01-27  224.020004  232.149994  223.979996  229.860001   94863400
# 2025-01-28  230.850006  240.190002  230.809998  238.259995   75707600
# 2025-01-29  234.119995  239.860001  234.009995  239.360001   45486100
# 2025-01-30  238.669998  240.789993  237.210007  237.589996   55658300
# 2025-01-31  247.190002  247.190002  233.440002  236.000000  100959800
#
#             dividend
# date
# 2021-12-07       0.0
# 2021-12-08       0.0
# 2021-12-09       0.0
# 2021-12-10       0.0
# 2021-12-13       0.0
# ...              ...
# 2025-01-27       0.0
# 2025-01-28       0.0
# 2025-01-29       0.0
# 2025-01-30       0.0
# 2025-01-31       0.0
#
# [471 rows x 6 columns]

# %% [markdown]
# Selects the first column where 'close' is greater than the mean 'close' value

# %%
df[df.close > df.close.mean()].iloc[:, 0]
# Out:
# date
# 2021-12-07    169.080002
# 2021-12-08    172.130005
# 2021-12-09    174.910004
# 2021-12-10    175.210007
# 2021-12-13    181.119995
#                  ...
# 2025-01-27    224.020004
# 2025-01-28    230.850006
# 2025-01-29    234.119995
# 2025-01-30    238.669998
# 2025-01-31    247.190002
# Name: open, Length: 471, dtype: float64

# %% [markdown]
# Uses multiple conditions to filter the DataFrame

# %%
df.loc[
    (df.close > df.close.mean())
    & (df.close.mean() > 100)
    & (df.volume > df.volume.mean())
]
# Out:
#                   open        high         low       close     volume  \
# date
# 2021
# 2023-07-18  193.350006  194.330002  192.419998  193.729996  48353800       0.0
# 2023-07-19  193.100006  198.229996  192.649994  195.100006  80507300       0.0
# 2023-07-20  195.089996  196.470001  192.500000  193.130005  59581200       0.0
# 2023-07-21  194.100006  194.970001  191.229996  191.940002  71917800       0.0
# 2023-07-24  193.410004  194.910004  192.250000  192.750000  45377800       0.0
# 2023-07-25  193.330002  194.440002  192.919998  193.619995  37283200       0.0
# 2023-07-26  193.669998  195.639999  193.320007  194.500000  47471900       0.0
# 2023-07-27  196.020004  197.199997  192.550003  193.220001  47460200       0.0
# 2023-07-28  194.669998  196.630005  194.139999  195.830002  48291400       0.0
# 2023-07-31  196.059998  196.490005  195.259995  196.449997  38824100       0.0

# %% [markdown]
# Accesses the 'close' value on 2023-07-12

# %%
df.at["2023-07-12", "close"]
# Out:
# np.float64(189.77000427246094)

# %% [markdown]
# Selects the top 5 rows with the highest 'volume'

# %%
df.nlargest(5, "volume")
# Out:
#                   open        high         low       close     volume  \
# date
# 2024-09-20  229.970001  233.089996  227.619995  228.199997  318679900
# 2024-06-21  210.389999  211.889999  207.110001  207.490005  246421400
# 2024-06-12  207.369995  220.199997  206.899994  213.070007  198134300
# 2021-12-17  169.929993  173.470001  169.690002  171.139999  195432700
# 2021-03-19  119.900002  121.430000  119.680000  119.989998  185549500
#
#             dividend
# date
# 2024-09-20       0.0
# 2024-06-21       0.0
# 2024-06-12       0.0
# 2021-12-17       0.0
# 2021-03-19       0.0

# %% [markdown]
# Queries the DataFrame to select rows where 'close' is greater than 'open'

# %%
df.query("close > open")
# Out:
#                   open        high         low       close     volume  \
# date
# 2021-01-05  128.889999  131.740005  128.429993  131.009995   97664900
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  109578200
# 2021-01-12  128.500000  129.690002  126.860001  128.800003   91951100
# 2021-01-13  128.759995  131.449997  128.490005  130.889999   88636800
# 2021-01-19  127.779999  128.710007  126.940002  127.830002   90757300
# ...                ...         ...         ...         ...        ...
# 2025-01-15  234.639999  238.960007  234.429993  237.869995   39832000
# 2025-01-22  219.789993  224.119995  219.789993  223.830002   64126500
# 2025-01-27  224.020004  232.149994  223.979996  229.860001   94863400
# 2025-01-28  230.850006  240.190002  230.809998  238.259995   75707600
# 2025-01-29  234.119995  239.860001  234.009995  239.360001   45486100
#
#             dividend
# date
# 2021-01-05       0.0
# 2021-01-07       0.0
# 2021-01-12       0.0
# 2021-01-13       0.0
# 2021-01-19       0.0
# ...              ...
# 2025-01-15       0.0
# 2025-01-22       0.0
# 2025-01-27       0.0
# 2025-01-28       0.0
# 2025-01-29       0.0
#
# [549 rows x 6 columns]

# %% [markdown]
# **Jason Strimpel** is the founder of <a href='https://pyquantnews.com/'>PyQuant News</a> and co-founder of <a href='https://www.tradeblotter.io/'>Trade Blotter</a>. His career in algorithmic trading spans 20+ years. He previously traded for a Chicago-based hedge fund, was a risk manager at JPMorgan, and managed production risk technology for an energy derivatives trading firm in London. In Singapore, he served as APAC CIO for an agricultural trading firm and built the data science team for a global metals trading firm. Jason holds degrees in Finance and Economics and a Master's in Quantitative Finance from the Illinois Institute of Technology. His career spans America, Europe, and Asia. He shares his expertise through the <a href='https://pyquantnews.com/subscribe-to-the-pyquant-newsletter/'>PyQuant Newsletter</a>, social media, and has taught over 1,000+ algorithmic trading with Python in his popular course **<a href='https://gettingstartedwithpythonforquantfinance.com/'>Getting Started With Python for Quant Finance</a>**. All code is for educational purposes only. Nothing provided here is financial advise. Use at your own risk.
